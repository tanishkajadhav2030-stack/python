# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\lenovo\OneDrive\Pictures\certificate\Social_Network_Ads.csv")

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
#check minimum and maximum values in age and salary

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
plt.hist(df['Age'])
# Out:
# (array([28., 37., 46., 35., 77., 65., 35., 31., 18., 28.]),
#  array([18. , 22.2, 26.4, 30.6, 34.8, 39. , 43.2, 47.4, 51.6, 55.8, 60. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(16,9))
plt.scatter(df['Age'],df['EstimatedSalary'],c=df
    ['Purchased']);
plt.title("data_distribution")
# Out:
# Text(0.5, 1.0, 'data_distribution')

# %%
#seperate the data

# %%
x=df[['Age','EstimatedSalary']]

# %%
x
# Out:
#       Age  EstimatedSalary
# 0    19.0          19000.0
# 1    35.0          20000.0
# 2    26.0          43000.0
# 3    27.0          57000.0
# 4    19.0          76000.0
# ..    ...              ...
# 395  46.0          41000.0
# 396  51.0          23000.0
# 397  50.0          20000.0
# 398  36.0          33000.0
# 399  49.0          36000.0
#
# [400 rows x 2 columns]

# %%
#normalization

# %%
from sklearn.preprocessing import MinMaxScaler
sca=MinMaxScaler()
x_scaled=sca.fit_transform(x)

# %%
x_scaled
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
x_scaled[:,0].min()
# Out:
# np.float64(0.0)

# %%
x_scaled[:,0].max()
# Out:
# np.float64(0.9999999999999998)

# %%
x_scaled[:,1].min()
# Out:
# np.float64(0.0)

# %%
x_scaled[:,1].max()
# Out:
# np.float64(1.0)

# %%
#plot the scatter chart to check the distribution

# %%
plt.figure(figsize=(16,9))
plt.title("data_distribution")
plt.scatter(x_scaled[:,1],x_scaled[:,0],c=df['Purchased']);

# %%
#standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
sca=StandardScaler()
x_scaled=sca.fit_transform(x)

# %%
x_scaled[:,0].min(),x_scaled[:,0].max()
# Out:
# (np.float64(-1.8773105578331641), np.float64(2.134240875847471))

# %%
x_scaled[:,1].min(),x_scaled[:,1].max()
# Out:
# (np.float64(-1.6075056615492507), np.float64(2.3567499772898386))
