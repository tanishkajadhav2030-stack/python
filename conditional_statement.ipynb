# %%
# if statement

# %%
number =10

# %%
if number < 0:
    print("positive number")

# %%
number = -5

# %%
if number > 0:
    print("negative number")

# %%
number = -5

# %%
if number < 0:
    print("positive number")
# Out:
# positive number

# %%
# if...else statement

# %%
age = 16

# %%
if age >= 18:
    print("adult")
else:
    print("minor")
# Out:
# minor

# %%
if input %2==0:
      print("even")
else:
      print("odd")
# Out:
# odd

# %%
number = 16

# %%
if number %2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
#if ...elif...statement

# %%
marks = 82

# %%
if marks >= 90:
    print("grade A")
elif marks >= 75:
    print("grade B")
elif marks >= 50:
    print("grade C")
else:
    print("fail")
# Out:
# grade B

# %%
# multiple conditions ising AND

# %%
age = 25
salary = 40000

# %%
if age >= 18 and salary >=3000:
    print("eligible for loan")
else:
    print("not eligible")
# Out:
# eligible for loan

# %%
year=int(input("enter your year:"))
if year % 4 ==0:
    print ("year is leap:")
else:
    print("year is not leap:")
# Out:
# enter your year: 2004
# year is leap:
