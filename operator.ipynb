# %%
#arthmetic operator

# %%
a = 10
b = 3

# %%
#addition

# %%
a+b
# Out:
# 13

# %%
#substraction

# %%
a-b
# Out:
# 7

# %%
#multiplication

# %%
a*b
# Out:
# 30

# %%
#division

# %%
a/b
# Out:
# 3.3333333333333335

# %%
#modules

# %%
a%b
# Out:
# 1

# %%
#floor division

# %%
a//b
# Out:
# 3

# %%
#comparision operator

# %%
x = 10
y = 5

# %%
#equal to

# %%
x == y
# Out:
# False

# %%
# not equal

# %%
x != y
# Out:
# True

# %%
#greater than

# %%
x<y
# Out:
# False

# %%
#less than

# %%
x>y
# Out:
# True

# %%
#greater than equal to

# %%
x<=y
# Out:
# False

# %%
#less than equal to

# %%
x>=y
# Out:
# True

# %%
#logical operator

# %%
# and: returns True only if both condtions are True
# or: returns True if at least one condition is True 
# not: reverse the result , inverting True to False and vice verse

# %%
a=True
b=False

# %%
# AND

# %%
a and b
# Out:
# False

# %%
# OR

# %%
a or b
# Out:
# True

# %%
# NOT

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# assignment operator

# %%
x = 5

# %%
x=x+5

# %%
print(x)
# Out:
# 30

# %%
x = x+5

# %%
print(x)
# Out:
# 35

# %%
x=x-30

# %%
print(x)
# Out:
# 5

# %%
x=x+x

# %%
print(x)
# Out:
# 10

# %%
# x= x -2

# %%
x-=2

# %%
print(x)
# Out:
# 8

# %%
# x = x*4

# %%
x*=4

# %%
print(x)
# Out:
# 32

# %%
x*=4

# %%
x
# Out:
# 512

# %%
#x = x/4

# %%
x/=4

# %%
x
# Out:
# 128.0

# %%
# membership operator

# %%
fruits=["apple","banana","grapes"]

# %%
"apple" in fruits
# Out:
# True

# %%
"apple" in fruits
# Out:
# True

# %%
"banana" in fruits
# Out:
# True

# %%
"mango" in fruits
# Out:
# False

# %%
#identity operator

# %%
a=[1,2,3]
b=a
c=[1,2,3]

# %%
a is b
# Out:
# True

# %%
a is c
# Out:
# False

# %%
b is c
# Out:
# False

# %%
c is a
# Out:
# False

# %%
a is not c
# Out:
# True

# %%
#bitwise operator
