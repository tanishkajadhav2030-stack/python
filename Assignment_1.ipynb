# %%
#1.	Write a Python program to declare variables of different data types, display their values, and print their data types

# %%
#string

# %%
Name="Tanishka"

# %%
print(Name)

# %%
print(type(Name))

# %%
#int

# %%
Age=17

# %%
print(Age)

# %%
print(type(17))

# %%
#float

# %%
Marks=80.5

# %%
print(Marks)

# %%
print(type(Marks))

# %%
#Boolean

# %%
flag=True

# %%
print(flag)

# %%
print(type(flag))

# %%
#2.	Write a Python program to accept two numbers from the user, perform all arithmetic operations, and display the results.

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))

# %%
#addition

# %%
a+b

# %%
#subtraction

# %%
a-b

# %%
#multiplication

# %%
a*b

# %%
#division

# %%
a/b

# %%
#modules

# %%
a%b

# %%
#floor division

# %%
a//b

# %%
#3.	Write a Python program to compare two numbers, display the comparison results, and identify the larger number.

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))

# %%
print(a==b)
print(a>b)
print(a<b)
print(a!=b)
print(a>=b)
print(a<=b)

# %%
#identify number

# %%
if a>b:
    print("first number is greater")
elif a<b:
    print("second number is larger")
else:
    ("both numbers are equal")

# %%
#4.	Write a Python program to print numbers from 1 to 50, display all even numbers, and calculate their sum.

# %%
sum= 0

for i in range (1,51):
    if i%2==0:
        print(i)
        sum +=i

# %%
print("sum=",sum)

# %%
#5.	Write a Python program to generate the multiplication table of a number, display the square of each multiple, and count the total multiples generated.

# %%
#table of multiplication number

# %%
a=9

# %%
for i in range(1, 11):
    print(a, "x", i, "=",a*i)

# %%
#display square

# %%
for i in range (1,11):
    multiple =a*i
    square= multiple**2
    print("multiple=",multiple ,"square=",square)

# %%
#count

# %%
count=0
for i in range (1,11):
    print(a*i)
    count+=1
print("total multiple generated=",count)

# %%
#6.	Write a Python program to calculate the factorial of a number, count its digits, and display the reverse of the number.

# %%
a= int(input("Enter a number: "))

# Factorial
fact = 1
for i in range(1, a+ 1):
    fact *= i

# Count digits
digits = len(str(a))

# Reverse number
reverse = str(a)[::-1]

print("Factorial =", fact)
print("Number of digits =", digits)
print("Reverse =", reverse)

# %%
#7.	Write a Python program to generate the Fibonacci series, calculate its sum, and display the largest term generated.

# %%
n=int(input("enter number of terms:"))
a=1
b=2
for i in range (n):
    print(a,end=" ")
    a, b= b, a+ b

# %%
#calculate its sum

# %%
a+b

# %%
#display largest term

# %%
a=1
b=2
for i in range(n):
    largest=a
    a,b=b,a+b
print("largest term=",largest)

# %%
#8.	Write a Python program to create a list of numbers, find the largest element, and calculate the sum of all elements.

# %%
#create list

# %%
l1=[1,2,3,4,5]

# %%
print(l1)

# %%
#find large number

# %%
max(l1)

# %%
#calculate sum of all elements

# %%
total=0
for i in l1:
    total=total+i
print("sum=",total)

# %%
#9.	Write a Python program to remove duplicate elements from a list, sort the list, and display its length.

# %%
#duplicate element list

# %%
num=[1,2,3,4,5,6,5,4,3,3]

# %%
list(set(num))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#sort the list

# %%
#ascending order

# %%
num.sort()

# %%
print(num)

# %%
#decending order

# %%
num.sort(reverse=True)

# %%
print(num)

# %%
#10 Write a Python program to count the occurrences of an element in a list, find its first position, and replace it with another value.

# %%
numbers = [1,2,3,4,5]

# %%
#find first position

# %%
numbers.index(1)

# %%
#replace with another

# %%
numbers[2]=15

# %%
print(num)

# %%
#count

# %%
numbers.count(2)

# %%
#11 Write a Python program to reverse a string, count the vowels, and count the consonants.

# %%
string="python"

# %%
#reverse string

# %%
print(string[::-1])

# %%
#count

# %%
count = 0
for ch in string.lower():
    if ch in "aeiou":
        count += 1
print("Vowels =", count)
count = 0
for ch in string.lower():
    if ch.isalpha() and ch not in "aeiou":
        count += 1
print("Consonants =", count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 count = 0
# ----> 2 for ch in string.lower():
#       3     if ch in "aeiou":
#       4         count += 1
#
# NameError: name 'string' is not defined

# %%
#12 Writea Python program to check whether a string is a palindrome, count the number of words, and convert it to uppercase.

# %%
text="hello"

# %%
text

# %%
text.upper()

# %%
words=text.split()
len(words)

# %%
#13 Write a Python program to create a dictionary, add a new key-value pair, and display all keys and values separately.

# %%
stu={
    "name":"tanishka",
    "age":17,
    "course":"Information Technology"
}

# %%
#add new key

# %%
stu["age"]=21

# %%
stu

# %%
#add new value

# %%
stu["std"]="TYIT"

# %%
stu

# %%
#display key

# %%
for key in stu:
    key
    print(key)

# %%
#display value

# %%
for value in stu.values():
    value
    print(value)

# %%
#14 Write a Python program to perform union, intersection, and difference operations on two sets.

# %%
a={10,20,30,40,50}
b={10,20,50,90,60}

# %%
#union

# %%
a.union(b)

# %%
#intersection

# %%
a.intersection(b)

# %%
#difference

# %%
a.difference(b)

# %%
#15 Write a Python program to create a tuple, count the occurrences of an element, and find its index position.

# %%
t=(1,2,3,4,5)

# %%
#count

# %%
t.count(1)

# %%
#find index position

# %%
t.index(3)

# %%
#16 Write a Python program to create a nested list, access its elements, and calculate the sum of all numeric values.

# %%
#create list

# %%
n_list=[[10,20],[30,40],[50]]

# %%
#aceess list element

# %%
n_list[1]

# %%
#calculaye sum

# %%
total=0
for sublist in n_list:
    for value in sublist:
        total=total+value
print("sum of numeric values=",total)

# %%
#17 Write a Python program to accept marks of five subjects, calculate the total, percentage, and average.

# %%
#access marks

# %%
python =int(input("enter marks of python"))
java=int(input("enter marks of java"))
oop=int(input("enter marks of oop"))
c=int(input("enter marks of c"))
DSU=int(input("enter marks of DSU"))

# %%
#calculate total

# %%
total=python+java+oop+c+DSU

# %%
print(total)

# %%
#percentage

# %%
(395/500)*100

# %%
##average

# %%
395/5

# %%
# 18.Write a Python program to create a user-defined module, import the module, and call its functions.

# %%
#create user defined module

# %%
# %%writefile mymodule.py
def add(a,b):
    return a+b
# Out:
# Overwriting mymodule.py

# %%
import mymodule

# %%
#call function

# %%
print(mymodule.add(10,5))
# Out:
# 15

# %%
#19.Write a Python program to use the math module to calculate square root, power, and factorial.

# %%
import math
n=5
print("Square root:", math.sqrt(n))
print("Power (2^3):", math.pow(2, 3))
print("Factorial:", math.factorial(n))
# Out:
# Square root: 2.23606797749979
# Power (2^3): 8.0
# Factorial: 120

# %%
#20.Write a Python program to use the random module to generate random integers, random floating-point numbers, and random choices from a list.

# %%
#generate random integer

# %%
import random
print("Random Integer:",random.randint(1,100))
# Out:
# Random Integer: 51

# %%
 #random floating-point numbers

# %%
import random
print("Random Float",random.random())
# Out:
# Random Float 0.8145188975668649

# %%
#random choice from list

# %%
import random
fruits = ["apple","banana","mango","orange"]
print("Random Choice",random.choice(fruits))
# Out:
# Random Choice banana

# %%
#21.Write a Python program to use the datetime module to display the current date, current time, and the day of the week.

# %%
# display the current date,current time, and the day of the week.

# %%
from datetime import datetime
now = datetime.now()
print("Current Date",now.date())
print("Current Time",now.strftime("%H:%M:%S"))
print("Day of Week",now.strftime("%A"))
# Out:
# Current Date 2026-06-16
# Current Time 10:35:20
# Day of Week Tuesday

# %%
 #22.Write a Python program to use the os module to display the current working directory, list all files, and create a new directory.

# %%
#display current working directory

# %%
import os
print("Current Working Directory",os.getcwd())
# Out:
# Current Working Directory C:\Users\lenovo

# %%
# List all files

# %%
import os
print("Files in current directory:")
print(os.listdir())
# Out:
# Files in current directory:
# ['.anaconda', '.conda', '.continuum', '.eclipse', '.gitconfig', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.p2', '.python_history', '.vscode', '.vscode-shared', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'Assignment_1.ipynb', 'Assignment_2.ipynb', 'Assignment_3.ipynb', 'Assignment_4.ipynb', 'basic python.txt', 'basicpython.ipynb', 'conditional_statement.ipynb', 'Contacts', 'Cookies', 'datastructure.ipynb', 'datastructure1.ipynb', 'datatype.ipynb', 'datatypes.ipynb', 'DLLs', 'Doc', 'Documents', 'Downloads', 'eclipse', 'eclipse-workspace', 'error_handling.ipynb', 'Favorites', 'filehandling.ipynb', 'Functions.ipynb', 'include', 'internship', 'java.txt', 'Lib', 'libs', 'LICENSE.txt', 'Links', 'Local Settings', 'loop in python.ipynb', 'loop_in _python.ipynb', 'main.py', 'Music', 'My Documents', 'mymodule.py', 'NetHood', 'NEWS.txt', 'new_fol', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{fa1bc959-2e68-11f0-9fda-901057c35748}.TM.blf', 'NTUSER.DAT{fa1bc959-2e68-11f0-9fda-901057c35748}.TM.blf.cnpf', 'NTUSER.DAT{fa1bc959-2e68-11f0-9fda-901057c35748}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{fa1bc959-2e68-11f0-9fda-901057c35748}.TMContainer00000000000000000001.regtrans-ms.cnpf', 'NTUSER.DAT{fa1bc959-2e68-11f0-9fda-901057c35748}.TMContainer00000000000000000002.regtrans-ms', 'NTUSER.DAT{fa1bc959-2e68-11f0-9fda-901057c35748}.TMContainer00000000000000000002.regtrans-ms.cnpf', 'ntuser.ini', 'object_oriented_programming.ipynb', 'OneDrive', 'operator.ipynb', 'pbstatement_operators.ipynb', 'practice.ipynb', 'PrintHood', 'python.exe', 'python.txt', 'python3.dll', 'python314.dll', 'pythonw.exe', 'Recent', 'sample.txt', 'Saved Games', 'Scripts', 'Searches', 'SendTo', 'Start Menu', 'statement.ipynb', 'tcl', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled10.ipynb', 'Untitled11.ipynb', 'Untitled12.ipynb', 'Untitled13.ipynb', 'Untitled14.ipynb', 'Untitled15.ipynb', 'Untitled16.ipynb', 'Untitled17.ipynb', 'Untitled18.ipynb', 'Untitled19.ipynb', 'Untitled2.ipynb', 'Untitled20.ipynb', 'Untitled21.ipynb', 'Untitled22.ipynb', 'Untitled23.ipynb', 'Untitled24.ipynb', 'Untitled25.ipynb', 'Untitled26.ipynb', 'Untitled27.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'Untitled9.ipynb', 'vcruntime140.dll', 'vcruntime140_1.dll', 'venv', 'Videos', '__pycache__']

# %%
# Create a new directory

# %%
import os
os.mkdir("Tanishka")
print("Directory created")
# Out:
# Directory created

# %%
# 23.Write a Python program to demonstrate list slicing, tuple slicing, and string slicing.

# %%
#list slicing

# %%
a=[1,2,3,4,5]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
#elements from index 1 to 3

# %%
a[1:4]
# Out:
# [2, 3, 4]

# %%
#from beginning to index 2

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
#tuple slicing

# %%
t=(10,20,30,40,50)

# %%
print(t)
# Out:
# (10, 20, 30, 40, 50)

# %%
#elements from index 0 to 2

# %%
t[:3]
# Out:
# (10, 20, 30)

# %%
#string slicing

# %%
s="Tanishka"

# %%
#elements from 2 to 4

# %%
s[2:5]
# Out:
# 'nis'

# %%
#24.Write a Python program to create a matrix using nested lists, display the matrix, and calculate row-wise sums.

# %%
#creating matrix using nested list

# %%
matrix=[
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
print("Matrix:")
for row in matrix:
    print(row)
# Out:
# Matrix:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
#calculate row wise

# %%
for row in matrix:
    print("Row sum",sum(row))
# Out:
# Row sum 6
# Row sum 15
# Row sum 24

# %%
#25.Write a Python program to accept N numbers from the user, store them in a list, and display the maximum, minimum, and average values.

# %%
#accept n numbers from user

# %%
n = int(input("Enter how many numbers"))
nums = []
for i in range(n):
    num = int(input("Enter number"))
    nums.append(num)
print("Numbers",nums)
# Out:
# Enter how many numbers 4
# Enter number 1
# Enter number 2
# Enter number 3
# Enter number 4
# Numbers [1, 2, 3, 4]

# %%
#store in list

# %%
print("List",nums)
# Out:
# List [1, 2, 3, 4]

# %%
#displya max,min,avg valuse

# %%
max(nums)
# Out:
# 4

# %%
min(nums)
# Out:
# 1

# %%
avg=sum(nums)/n

# %%
print(avg)
# Out:
# 2.5
