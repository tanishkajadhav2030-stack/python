# %%
li1={1,2,3,4,5}

# %%
li1
# Out:
# {1, 2, 3, 4, 5}

# %%
set(li1)
# Out:
# {1, 2, 3, 4, 5}

# %%
#intersection

# %%
#common elements

# %%
a={1,2,3}

# %%
b={2,3,6}

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
#copy

# %%
a={1,2,3}

# %%
b=a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
#frozenset
#nested set using frozenset
#normal set cannot contain set
#use frozen set for nested sets

# %%
a=frozenset({1,2})

# %%
b={a,3}

# %%
b
# Out:
# {3, frozenset({1, 2})}

# %%
#type

# %%
x=frozenset({4,5})

# %%
y={x,4}
type(x)
# Out:
# frozenset

# %%
#create dictonary

# %%
student={
    "name":"tanu",
    "age":17
}

# %%
#checkdatatype

# %%
print(student)
# Out:
# {'name': 'tanu', 'age': 17}

# %%
emp={
    "name":"samarth",
    "empid":101,
    "age":18,
    "salary":25000
}

# %%
print(emp)
# Out:
# {'name': 'samarth', 'empid': 101, 'age': 18, 'salary': 25000}

# %%
city={
    "name":"pune",
    "kilometer":60
}

# %%
print(city)
# Out:
# {'name': 'pune', 'kilometer': 60}

# %%
fruits={
    "name":"mango",
    "price":150
}

# %%
print(fruits)
# Out:
# {'name': 'mango', 'price': 150}

# %%
#mixed data type

# %%
mixed={
    3:"one",
    "name":"python",
    True:100
}

# %%
print(mixed)
# Out:
# {3: 'one', 'name': 'python', True: 100}

# %%
#access element

# %%
student["name"]
# Out:
# 'tanu'

# %%
#access get

# %%
student.get("age")
# Out:
# 17

# %%
#adding element

# %%
student={
    "name":"tanishka"
}

# %%
#add new key pair

# %%
student["age"]=21

# %%
student
# Out:
# {'name': 'tanishka', 'age': 21}

# %%
#add another value

# %%
student["std"]="TYIF"

# %%
student
# Out:
# {'name': 'tanishka', 'age': 21, 'std': 'TYIF'}

# %%
#modify

# %%
student["name"]="tanu"

# %%
student
# Out:
# {'name': 'tanu', 'age': 17, 'std': 'TYIF', 21: 17}

# %%
#remove

# %%
student.pop("name")
# Out:
# 'tanu'

# %%
student
# Out:
# {'age': 17, 'std': 'TYIF', 21: 17}

# %%
#remove last inserted item

# %%
student.popitem()
# Out:
# (21, 17)

# %%
student
# Out:
# {'age': 17, 'std': 'TYIF'}

# %%
#delete

# %%
del student["age"]

# %%
student
# Out:
# {'std': 'TYIF'}

# %%
#remove all dic

# %%
student.clear()

# %%
student
# Out:
# {}

# %%
#new dic

# %%
emp={
    "name":"samarth",
    "empid":101,
    "age":18,
    "salary":25000
}

# %%
len(emp)
# Out:
# 4

# %%
#checking key

# %%
"std" in emp
# Out:
# False

# %%
#loop through key

# %%
for key in emp:
    key
    print(key)
# Out:
# name
# empid
# age
# salary

# %%
for value in emp.values():
    value
    print(value)
# Out:
# samarth
# 101
# 18
# 25000

# %%
#both key and value

# %%
for items in emp.items():
    items
    print(items)
# Out:
# ('name', 'samarth')
# ('empid', 101)
# ('age', 18)
# ('salary', 25000)

# %%
emp.keys()
# Out:
# dict_keys(['name', 'empid', 'age', 'salary'])

# %%
emp.values()
# Out:
# dict_values(['samarth', 101, 18, 25000])

# %%
emp.items()
# Out:
# dict_items([('name', 'samarth'), ('empid', 101), ('age', 18), ('salary', 25000)])

# %%
#copy dic

# %%
s=emp.copy()

# %%
s
# Out:
# {'name': 'samarth', 'empid': 101, 'age': 18, 'salary': 25000}

# %%
#nested

# %%
students={
    "stu1":{
        "name":"rahul",
        "age":21
    },
    "stu2":{
    "name":"aman",
    "age":22
   }
}

# %%
students
# Out:
# {'stu1': {'name': 'rahul', 'age': 21}, 'stu2': {'name': 'aman', 'age': 22}}

# %%
#access nested values

# %%
students["stu1"]["name"]
# Out:
# 'rahul'
