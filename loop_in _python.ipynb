# %%
#loop

# %%
# Afor loop in python repeats a block of specific number of time by stepping through a collection of items

# %% [raw]
# # print numbers from 0 to 4

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#print numbers from 1 to 5

# %%
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
 fruits=["apple","mango","banana"]

# %%
for fruit in fruits:
    print(fruit)
# Out:
# apple
# mango
# banana

# %%
name=["pallavi","sayali","bhagu"]

# %%
for i in name:
    print(i)
# Out:
# pallavi
# sayali
# bhagu

# %%
#multiplication table

# %%
num = 5

# %%
for i in range(1,11):
    print(num,"x",i,"=",num*i)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
#while loop

# %%
i=1

# %%
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#break

# %%
#the break statement in python instantly stops and exit a loop

# %%
#stop loop at 5

# %%
for i in range (1,11):
    
    if i==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range (10,20):

    if i==15:
        break
    print(i)
# Out:
# 10
# 11
# 12
# 13
# 14

# %%
#continue

# %%
for i in range (10,20):

    if i==15:
        continue
    print(i)
# Out:
# 10
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19

# %%
password=" "
while password != "python":
    password=input("enter your password")
print("login succesfully")
# Out:
# enter your password python
# login succesfully

# %%
while amount !=0:
   amount=int(input("enter amount(0 to exit):"))
if amount == 0:
    break
print("enter amount:",amount)

# %%
n = int(input("enter a positive integer"))

factorial = 1

for i in range(1,n+1):
    factorial *=i
print("the factorial of {n} is {factorial}")
# Out:
# enter a positive integer 12
# the factorial of {n} is {factorial}
