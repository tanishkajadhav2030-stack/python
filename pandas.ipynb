# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pandas

# %%
#install pandas

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s=pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#dic

# %%
dic={
    "name":"Tanishka",
    "age":17,
    "marks":75
}

# %%
dic
# Out:
# {'name': 'Tanishka', 'age': 17, 'marks': 75}

# %%
s=pd.Series(dic)

# %%
s
# Out:
# name     Tanishka
# age            17
# marks          75
# dtype: object

# %%
pd.Series(5,index=['0','1','2','3','4'])
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
s1=pd.Series([10,20,30],index=['a','b','c'])

# %% [markdown]
# #

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s1.values
# Out:
# array([10, 20, 30])

# %%
s1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s1.dtype
# Out:
# dtype('int64')

# %%
s1.shape
# Out:
# (3,)

# %%
s1*2
# Out:
# a    20
# b    40
# c    60
# dtype: int64

# %%
s1=pd.Series([10,None,30])

# %%
s1
# Out:
# 0    10.0
# 1     NaN
# 2    30.0
# dtype: float64

# %%
s1.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s1.dropna()
# Out:
# 0    10.0
# 2    30.0
# dtype: float64

# %%
s1.fillna(20)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# dtype: float64

# %%
s1=pd.Series([1,2,2,3,3,3])

# %%
s1
# Out:
# 0    1
# 1    2
# 2    2
# 3    3
# 4    3
# 5    3
# dtype: int64

# %%
s1.value_counts()
# Out:
# 3    3
# 2    2
# 1    1
# Name: count, dtype: int64

# %%
s=pd.Series([10,20,30,40],index=['a','b','c','d'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['b']
# Out:
# np.int64(20)

# %%
s['c']
# Out:
# np.int64(30)

# %%
s['d']
# Out:
# np.int64(40)

# %%
#create data frame(2D)

# %%
s=pd.DataFrame({
    "name":["Tanishka","Sayali"],
    "age":[17,16]
})

# %%
s
# Out:
#        name  age
# 0  Tanishka   17
# 1    Sayali   16

# %%
data={
    "roll_no":[100,200,300,400],
    "name":["omkar","shrwan","sayali","rahul"],
    "marks":[99,100,101,None]
}

# %%
data
# Out:
# {'roll_no': [100, 200, 300, 400],
#  'name': ['omkar', 'shrwan', 'sayali', 'rahul'],
#  'marks': [99, 100, 101, None]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    roll_no    name  marks
# 0      100   omkar   99.0
# 1      200  shrwan  100.0
# 2      300  sayali  101.0
# 3      400   rahul    NaN

# %%
d={
    "subject":["java","python","css"],
    "marks":[99,100,101],
    "grade":['A','B','C']
}

# %%
d
# Out:
# {'subject': ['java', 'python', 'css'],
#  'marks': [99, 100, 101],
#  'grade': ['A', 'B', 'C']}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#   subject  marks grade
# 0    java     99     A
# 1  python    100     B
# 2     css    101     C

# %%
df.to_csv('marks_data.csv',index=False)

# %%
df=pd.read_csv('marks_data.csv')

# %%
df
# Out:
#   subject  marks grade
# 0    java     99     A
# 1  python    100     B
# 2     css    101     C

# %%
df.head()
# Out:
#   subject  marks grade
# 0    java     99     A
# 1  python    100     B
# 2     css    101     C

# %%
df.tail()
# Out:
#   subject  marks grade
# 0    java     99     A
# 1  python    100     B
# 2     css    101     C

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['subject', 'marks', 'grade'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  3 non-null      object
#  1   marks    3 non-null      int64
#  2   grade    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#        marks
# count    3.0
# mean   100.0
# std      1.0
# min     99.0
# 25%     99.5
# 50%    100.0
# 75%    100.5
# max    101.0

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of    subject  marks  grade
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False>

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#   subject  marks grade
# 0    java     99     A
# 1  python    100     B
# 2     css    101     C

# %%
df['marks']=df['marks'].astype(float)

# %%
df
# Out:
#   subject  marks grade
# 0    java   99.0     A
# 1  python  100.0     B
# 2     css  101.0     C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  3 non-null      object
#  1   marks    3 non-null      float64
#  2   grade    3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df["subject"]
# Out:
# 0      java
# 1    python
# 2       css
# Name: subject, dtype: object

# %%
df[["subject","marks"]]
# Out:
#   subject  marks
# 0    java   99.0
# 1  python  100.0
# 2     css  101.0

# %%
df=df.sort_values(by="marks",ascending=False)

# %%
df
# Out:
#   subject  marks grade
# 2     css  101.0     C
# 1  python  100.0     B
# 0    java   99.0     A
