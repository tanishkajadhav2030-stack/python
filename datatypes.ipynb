# %%
# integer

# %%
# integer means whole numbers

# %%
age = 21

# %%
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
marks = 90

# %%
print(marks,type(marks))
# Out:
# 90 <class 'int'>

# %%
temperature = -5

# %%
print(temperature,type(temperature))
# Out:
# -5 <class 'int'>

# %%
# integer operations

# %%
a = 25
b = 10

# %%
# addition

# %%
a+b
# Out:
# 35

# %%
# substraction

# %%
a-b
# Out:
# 15

# %%
# multiplication

# %%
a*b
# Out:
# 250

# %%
# division

# %%
a/b
# Out:
# 2.5

# %%
# floor division

# %%
a//b
# Out:
# 2

# %%
# reminder

# %%
a%b
# Out:
# 5

# %%
# power

# %%
a**b
# Out:
# 95367431640625

# %%
# string

# %%
# string means text

# %%
first_name = "tanishka"
last_name = "jadhav"
course = "python"

# %%
print(first_name,type(first_name))
# Out:
# tanishka <class 'str'>

# %%
print(last_name,type(last_name))
# Out:
# jadhav <class 'str'>

# %%
print(course,type(course))
# Out:
# python <class 'str'>

# %%
full_name = first_name+ " " +last_name

# %%
full_name
# Out:
# 'tanishka jadhav'

# %%
# string repetition

# %%
word = "python "

# %%
print(word*3)
# Out:
# python python python

# %%
word = "python"

# %%
print(word*3)
# Out:
# pythonpythonpython

# %%
# string indexing

# %%
language="python"

# %%
language[0]
# Out:
# 'p'

# %%
language[1]
# Out:
# 'y'

# %%
language[-1]
# Out:
# 'n'

# %%
language[-2]
# Out:
# 'o'

# %%
# string slicing

# %%
language = "python programming"

# %%
language[0:6]
# Out:
# 'python'

# %%
language[7:18]
# Out:
# 'programming'

# %%
language[:7]
# Out:
# 'python '

# %%
language[:11]
# Out:
# 'python prog'

# %%
language[:18]
# Out:
# 'python programming'

# %%
language[-11]
# Out:
# 'p'

# %%
language[7:]
# Out:
# 'programming'

# %%
language[0:]
# Out:
# 'python programming'

# %%
# string method

# %%
message="welcome to python programming"

# %%
message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
message.lower()
# Out:
# 'welcome to python programming'

# %%
message.title()
# Out:
# 'Welcome To Python Programming'

# %%
message.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(message)
# Out:
# 29

# %%
#replace
#used to replace a word or chracter in a string

# %%
text = "i like java"

# %%
new_text=text.replace("java","python")

# %%
print(new_text)
# Out:
# i like python

# %%
text="i like coding"

# %%
new_text=text.replace("coding","creating website")

# %%
print(new_text)
# Out:
# i like creating website

# %%
# join

# %%
# used to join list items into a single string

# %%
words = ['python','is','easy']

# %%
sentence = " ".join(words)

# %%
print(sentence)
# Out:
# python is easy

# %%
words = ['sayli','is','a','boy']

# %%
sentence =" ".join(words)

# %%
print(sentence)
# Out:
# sayli is a boy

# %%
words = ['java','is','easy']

# %%
sentence = " ".join(words)

# %%
print(sentence)
# Out:
# java is easy

# %%
#strip

# %%
#used to remove extra spaces from the beginning and end of string

# %%
text=" python "

# %%
clean_text=text.strip()

# %%
clean_text
# Out:
# 'python'

# %%
#lstrip remove left spaces

# %%
text=" hello"

# %%
text.lstrip()
# Out:
# 'hello'

# %%
#rstrip remove right spaces

# %%
text="hello "

# %%
text.rstrip()
# Out:
# 'hello'

# %%
#string formating

# %%
#f-strings A modern and easy way to insert variable into string

# %%
name="rahul"
age=22

# %%
print(f"my name is {name}and i am {age}years old,")
# Out:
# my name is rahuland i am 22years old,

# %%
subject="java"

# %%
print(f"i like {subject},")
# Out:
# i like java,

# %%
subject1="css"
subject2="python"

# %%
print(f"i like {subject1} and  {subject2}")
# Out:
# i like css and  python

# %%
# mathematical operation inside f-string

# %%
a=10
b=5

# %%
print(f"sum={a+b}")
# Out:
# sum=15

# %%
print(f"mul={a*b}")
# Out:
# mul=50

# %%
print(f"div{a/b}")
# Out:
# div2.0

# %%
print(f"sub{a-b}")
# Out:
# sub5

# %%
#format

# %%
name="rahul"
age=22

# %% [raw]
# print("my name is {} and i am {} years old .".format(name,age))

# %%
print("my name is {} and i am {} years old .".format(name,age))
# Out:
# my name is rahul and i am 22 years old .

# %%
#boolean

# %%
#boolean has only two values :true and false

# %%
is_student = True
is_employed = False

# %%
print(is_student , type(is_student))
# Out:
# True <class 'bool'>

# %%
print(is_employed , type(is_employed))
# Out:
# False <class 'bool'>
